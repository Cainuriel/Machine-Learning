# %% [markdown]
# <a href="https://colab.research.google.com/github/Cainuriel/Machine-Learning/blob/master/Graficando_datos_basico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pylab as plt
import numpy as np

# %% [markdown]
# El siguiente ejemplo  se crea un gráfico a partir de una lista de valores. **En el eje "x"** se representan** 8 elementos numerados  y **en el eje "y"** los valores **de cada uno de ellos** siguiendo el orden de la lista.

# %%
lista1 = [11,2,3,15,8,13,21,34]   # Declara lista 1 con 8 valores
plt.plot(lista1)   # Dibuja el gráfico
plt.title("Goles en una temporada")   # Establece el título del gráfico
plt.xlabel("jugadores")   # Establece el título del eje x 
plt.ylabel("goles")   # Establece el título del eje y
plt.ioff()   # Desactiva modo interactivo de dibujo
lista2 = [2,3,4,2,3,6,4,10]   # Declara lista 2: goles de cabeza.
plt.ion()   # Activa modo interactivo de dibujo
plt.plot(lista2)   # Dibuja datos de lista2 sin borrar datos de lista1
lista3 = [9,15,9,15,9,15,9,15]   # Declara lista3 con 8 valores
plt.plot(lista3)   # dibuja datos de lista 3
plt.ion()   # Activa modo interactivo de dibujo
plt.show()  # Muestra cuadrícula del gráfico

# %% [markdown]
# Para añadir leyendas al gráfico anterior asignar al parámetro "label=" de plot() el literal de la leyenda a mostrar. Y después, ejecutar el método legend().

# %%
lista1 = [11,2,3,15,8,13,21,34]   # Declara lista 1 con 8 valores
plt.plot(lista1)   # Dibuja el gráfico
plt.title("Goles en una temporada")   # Establece el título del gráfico
plt.xlabel("jugadores")   # Establece el título del eje x 
plt.ylabel("goles")   # Establece el título del eje y
plt.ioff()   # Desactiva modo interactivo de dibujo
lista2 = [2,3,4,2,3,6,4,10]   # Declara lista 2: goles de cabeza.
plt.ion()   # Activa modo interactivo de dibujo
plt.plot(lista2)   # Dibuja datos de lista2 sin borrar datos de lista1
lista3 = [9,15,9,15,9,15,9,15]   # Declara lista3 con 8 valores
plt.plot(lista3)   # dibuja datos de lista 3
plt.ion()   # Activa modo interactivo de dibujo
plt.show()  # Muestra cuadrícula del gráfico

plt.plot(lista1, label = "Goles")
plt.plot(lista2, label = "de Cabeza")
plt.plot(lista3, label = "Compañero más cercano en goles")
plt.legend()

# %% [markdown]
# Para colocar la leyenda en la parte superior del gráfico y a la derecha: plt.legend(loc="upper right")

# %%
lista1 = [11,2,3,15,8,13,21,34]   # Declara lista 1 con 8 valores
plt.plot(lista1)   # Dibuja el gráfico
plt.title("Goles en una temporada")   # Establece el título del gráfico
plt.xlabel("jugadores")   # Establece el título del eje x 
plt.ylabel("goles")   # Establece el título del eje y
plt.ioff()   # Desactiva modo interactivo de dibujo
lista2 = [2,3,4,2,3,6,4,10]   # Declara lista 2: goles de cabeza.
plt.ion()   # Activa modo interactivo de dibujo
plt.plot(lista2)   # Dibuja datos de lista2 sin borrar datos de lista1
lista3 = [9,15,9,15,9,15,9,15]   # Declara lista3 con 8 valores
plt.plot(lista3)   # dibuja datos de lista 3
plt.ion()   # Activa modo interactivo de dibujo
plt.show()  # Muestra cuadrícula del gráfico

plt.plot(lista1, label = "Goles")
plt.plot(lista2, label = "de Cabeza")
plt.plot(lista3, label = "Compañero más cercano en goles")
plt.legend()

plt.legend(loc="upper right")

# %% [markdown]
# Cambiar estilos de línea, marcadores y colores de un gráfico
#
# Para dar claridad a los gráficos pueden establecerse distintos estilos de líneas, marcadores y colores:
#
# Estilos de Líneas (linestyle=):
# -, Línea Sólida
# --, Línea discontinua
# :, Línea punteada
# -., Línea punteada discontinua. y
# None, Ninguna línea
#
# Marcadores (marker=):
# +, Cruz
# ., Punto
# o,Círculo
# *, Estrellas
# p, Pentágonos
# s, cuadrados
# x, Tachados
# D, Diamantes
# h, Hexágonos y
# ^, Triángulos
#
# Colores (color=):
# b, blue
# g, green
# r, red
# c, cyan
# m, magenta
# y, yellow
# k, black
# w, white
#
# Ejemplo:
#
# : plt.plot(lista1, marker='x', linestyle=':', color='b', label = "Enero")
# : plt.plot(lista2, marker='*', linestyle='-', color='g', label = "Febrero")
# : plt.plot(lista3, marker='o', linestyle='--', color='r', label = "Marzo")
# : plt.legend(loc="upper left")

# %% [markdown]
# Añadir rótulos a los ejes
#
# En el siguiente ejemplo se crea un gráfico nuevo con el método figure() donde se representa sólo una lista de valores y se definen los rótulos de los ejes.

# %%
plt.figure()  # Comenzamos un nuevo gráfico (figura)
lista1 = [11,2,3,15,8,13,21,34]
plt.title("Goles de temporada")
plt.xlabel("Jugadores")
plt.ylabel("Goles")
indice = np.arange(8)   # Declara un array
plt.xticks(indice, ("Ronaldo", "Alcacer", "Correa", "Bencema", "Luis Suarez", "Diego Costa", "Messi", "Griezzmann"))   
plt.yticks(np.arange(0,51,10))
plt.plot(lista1)

# %% [markdown]
# - El array que se obtiene con np.arange(8) contiene los siguiente valores:
#
# array([0, 1, 2, 3, 4, 5, 6, 7])
#
# - El array que se obtiene con np.arange(0,51,10) contiene los siguiente valores:
#
# array([ 0, 10, 20, 30, 40, 50])
#
# Los arrays se utilizan para definir los rótulos que se mostrarán en ambos ejes. En el eje "x" el valor del índice es sustituido por los nombtres de los jugadores  y en el eje "y", directamente, se muestran en la escala los valores del propio array.

# %% [markdown]
# **Trabajar con varios gráficos**
#
# ---
#
#
#
# ---
#
#
#
# - Activar gráfico por su número:
#
# Si estamos trabajando con varios gráficos a la vez para activar uno concreto indicaremos el nombre. Cualquier acción que se realice a continuación se hará sobre dicho gráfico: plt.figure(Nombre)

# %%
plt.figure('Regiones')
# llamamos a Dispersion
plt.figure('Dispersión')
elementosx = np.random.rand(10)   # Genera al azar un array de 10 elementos eje x
elementosy = np.random.rand(10)   # Genera al azar un array de 10 elementos eje y
plt.title("Dispersion")
plt.scatter(elementosx, elementosy) # con puntos.
# llamamos a Regiones
plt.figure('Regiones')
plt.title("Regiones")
elementosx = np.random.rand(10)   # Genera al azar un array de 10 elementos eje x
elementosy = np.random.rand(10)   # Genera al azar un array de 10 elementos eje y
plt.plot(elementosx,elementosy)

# %%
# Dividir la ventana en 1 fila x 2 columnas y dibujar primer gráfico

plt.subplot(1,2,1)
plt.plot((1,2,3,4,5))

# Dividir la ventana en 1 fila x 2 columnas y dibujar segundo gráfico

plt.subplot(1,2,2)
plt.plot((5,4,3,2,1))

# %%
# Para guardar la imagen de un gráfico en un archivo:

# plt.savefig("archivo.png")   # Guardar en formato .png
# plt.savefig("archivo.pdf")   # Guardar en formato .pdf

# %% [markdown]
# Dibujar un gráfico de barras horizontales

# %%
paises = ("Alemania", "España", "Francia", "Portugal")
posicion_y = np.arange(len(paises))
unidades = (342, 321, 192, 402)
plt.barh(posicion_y, unidades, align = "center")
plt.yticks(posicion_y, paises)
plt.xlabel('Unidades vendidas')
plt.title("Ventas en Europa")
# Out:
# Text(0.5,1,'Ventas en Europa')

# %% [markdown]
# Dibujar un gráfico de mútiples barras verticales

# %%
datos = [[1, 2, 3, 4], [3, 5, 3, 5], [8, 6, 4, 2]]
X = np.arange(4)
plt.bar(X + 0.00, datos[0], color = "b", width = 0.25)
plt.bar(X + 0.25, datos[1], color = "g", width = 0.25)
plt.bar(X + 0.50, datos[2], color = "r", width = 0.25)
plt.xticks(X+0.38, ["Enero","Febrero","Marzo","Abril"])
# Out:
# ([<matplotlib.axis.XTick at 0x7fa66aa994e0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %% [markdown]
# Dibujar un gráfico circular

# %%
impr = ["PP", "Ciudadanos", "PSOE", "Podemos"]
vol = [25, 31, 46, 10]
expl =(0, 0, 0.1, 0) # corte en la tarta.
plt.pie(vol, explode=expl, labels=impr, autopct='%1.1f%%', shadow=True)
plt.title("Votos en Andalucia", bbox={"facecolor":"0.8", "pad":5})
plt.legend(loc="lower left")
